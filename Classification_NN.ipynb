# %% [markdown]
# <a href="https://colab.research.google.com/github/mknair75/machine_learning/blob/main/Classification_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles

# %%
X,y = make_circles(1000,noise = 0.03, random_state =42)

# %%
X[:10]
# Out:
# array([[ 0.75424625,  0.23148074],
#        [-0.75615888,  0.15325888],
#        [-0.81539193,  0.17328203],
#        [-0.39373073,  0.69288277],
#        [ 0.44220765, -0.89672343],
#        [-0.47964637,  0.67643477],
#        [-0.01364836,  0.80334872],
#        [ 0.77151327,  0.14775959],
#        [-0.16932234, -0.79345575],
#        [-0.1214858 ,  1.02150905]])

# %%
y[:10]
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 1, 0])

# %%
import pandas as pd
circles = pd.DataFrame({"X0":X[:,0],"X1":X[:,1],"label":y})
circles
# Out:
#            X0        X1  label
# 0    0.754246  0.231481      1
# 1   -0.756159  0.153259      1
# 2   -0.815392  0.173282      1
# 3   -0.393731  0.692883      1
# 4    0.442208 -0.896723      0
# ..        ...       ...    ...
# 995  0.244054  0.944125      0
# 996 -0.978655 -0.272373      0
# 997 -0.136900 -0.810012      1
# 998  0.670362 -0.767502      0
# 999  0.281057  0.963824      0
#
# [1000 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y,cmap=plt.cm.RdYlBu)

# %%
import tensorflow as tf
import numpy as np

tf.random.set_seed(42)
model = tf.keras.Sequential([
      tf.keras.layers.Dense(100), # add 100 dense neurons
      tf.keras.layers.Dense(10),
      tf.keras.layers.Dense(1)
      #tf.keras.Input(shape=1),
      #tf.keras.layers.Dense(100,activation="relu"),
      #tf.keras.layers.Dense(2,activation="softmax")                       
])

model.compile(loss=tf.keras.losses.BinaryCrossentropy(),
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])
model.fit(X,y,epochs=100, verbose=0)

# %%
def plot_decision_boundary(model, X, y):
  """
  Plots the decision boundary created by a model predicting on X.
  This function has been adapted from two phenomenal resources:
   1. CS231n - https://cs231n.github.io/neural-networks-case-study/
   2. Made with ML basics - https://github.com/GokuMohandas/MadeWithML/blob/main/notebooks/08_Neural_Networks.ipynb
  """
  # Define the axis boundaries of the plot and create a meshgrid
  x_min, x_max = X[:, 0].min() - 0.1, X[:, 0].max() + 0.1
  y_min, y_max = X[:, 1].min() - 0.1, X[:, 1].max() + 0.1
  xx, yy = np.meshgrid(np.linspace(x_min, x_max, 100),
                       np.linspace(y_min, y_max, 100))
  
  # Create X values (we're going to predict on all of these)
  x_in = np.c_[xx.ravel(), yy.ravel()] # stack 2D arrays together: https://numpy.org/devdocs/reference/generated/numpy.c_.html
  
  # Make predictions using the trained model
  y_pred = model.predict(x_in)

  # Check for multi-class
  if len(y_pred[0]) > 1:
    print("doing multiclass classification...")
    # We have to reshape our predictions to get them ready for plotting
    y_pred = np.argmax(y_pred, axis=1).reshape(xx.shape)
  else:
    print("doing binary classifcation...")
    y_pred = np.round(y_pred).reshape(xx.shape)
  
  # Plot decision boundary
  plt.contourf(xx, yy, y_pred, cmap=plt.cm.RdYlBu, alpha=0.7)
  plt.scatter(X[:, 0], X[:, 1], c=y, s=40, cmap=plt.cm.RdYlBu)
  plt.xlim(xx.min(), xx.max())
  plt.ylim(yy.min(), yy.max())

# %%
plot_decision_boundary(model, X, y)
# Out:
# doing binary classifcation...

# %%
tf.random.set_seed(42)
model_2 = tf.keras.Sequential([
      tf.keras.layers.Dense(4,activation="relu"),
      tf.keras.layers.Dense(4,activation="relu"),
      tf.keras.layers.Dense(1,activation="sigmoid")
])
model_2.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(0.001),
                metrics =["accuracy"])
model_2.fit(x=X,y=y, epochs=250,verbose=0)

# %%
model_2.evaluate(X,y)
# Out:
# 32/32 [==============================] - 0s 760us/step - loss: 0.0459 - accuracy: 0.9920
# [0.04593365266919136, 0.9919999837875366]

# %%
plot_decision_boundary(model=model_2,
                       X=X,
                       y=y)
# Out:
# doing binary classifcation...

# %%
X_train,y_train = X[:800],y[:800]

# %%
X_train.shape
# Out:
# (800, 2)

# %%
y_train.shape
# Out:
# (800,)

# %%
X_test,y_test = X[800:],y[800:]

# %%
tf.random.set_seed(42)
model_4 = tf.keras.Sequential([
  tf.keras.layers.Dense(4,activation="relu"),
  tf.keras.layers.Dense(4,activation="relu"),
  tf.keras.layers.Dense(1,activation="sigmoid"),
])

model_4.compile(loss=tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=["accuracy"])
history = model_4.fit(X_train,y_train,epochs=25)
# Out:
# Epoch 1/25
# 25/25 [==============================] - 0s 878us/step - loss: 0.6847 - accuracy: 0.5425
# Epoch 2/25
# 25/25 [==============================] - 0s 973us/step - loss: 0.6777 - accuracy: 0.5525
# Epoch 3/25
# 25/25 [==============================] - 0s 854us/step - loss: 0.6736 - accuracy: 0.5512
# Epoch 4/25
# 25/25 [==============================] - 0s 931us/step - loss: 0.6681 - accuracy: 0.5775
# Epoch 5/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6633 - accuracy: 0.5850
# Epoch 6/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6546 - accuracy: 0.5838
# Epoch 7/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6413 - accuracy: 0.6750
# Epoch 8/25
# 25/25 [==============================] - 0s 865us/step - loss: 0.6264 - accuracy: 0.7013
# Epoch 9/25
# 25/25 [==============================] - 0s 917us/step - loss: 0.6038 - accuracy: 0.7487
# Epoch 10/25
# 25/25 [==============================] - 0s 858us/step - loss: 0.5714 - accuracy: 0.7738
# Epoch 11/25
# 25/25 [==============================] - 0s 949us/step - loss: 0.5404 - accuracy: 0.7650
# Epoch 12/25
# 25/25 [==============================] - 0s 985us/step - loss: 0.5015 - accuracy: 0.7837
# Epoch 13/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.7975
# Epoch 14/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4113 - accuracy: 0.8450
# Epoch 15/25
# 25/25 [==============================] - 0s 863us/step - loss: 0.3625 - accuracy: 0.9125
# Epoch 16/25
# 25/25 [==============================] - 0s 937us/step - loss: 0.3209 - accuracy: 0.9312
# Epoch 17/25
# 25/25 [==============================] - 0s 938us/step - loss: 0.2847 - accuracy: 0.9488
# Epoch 18/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2597 - accuracy: 0.9525
# Epoch 19/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.9563
# Epoch 20/25
# 25/25 [==============================] - 0s 974us/step - loss: 0.2135 - accuracy: 0.9663
# Epoch 21/25
# 25/25 [==============================] - 0s 999us/step - loss: 0.1938 - accuracy: 0.9775
# Epoch 22/25
# 25/25 [==============================] - 0s 972us/step - loss: 0.1752 - accuracy: 0.9737
# Epoch 23/25
# 25/25 [==============================] - 0s 991us/step - loss: 0.1619 - accuracy: 0.9787
# Epoch 24/25
# 25/25 [==============================] - 0s 976us/step - loss: 0.1550 - accuracy: 0.9775
# Epoch 25/25
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1490 - accuracy: 0.9762

# %%
df = pd.DataFrame(history.history)
df
# Out:
#         loss  accuracy
# 0   0.684651   0.54250
# 1   0.677721   0.55250
# 2   0.673595   0.55125
# 3   0.668149   0.57750
# 4   0.663269   0.58500
# 5   0.654567   0.58375
# 6   0.641258   0.67500
# 7   0.626428   0.70125
# 8   0.603831   0.74875
# 9   0.571404   0.77375
# 10  0.540443   0.76500
# 11  0.501504   0.78375
# 12  0.468332   0.79750
# 13  0.411302   0.84500
# 14  0.362506   0.91250
# 15  0.320904   0.93125
# 16  0.284708   0.94875
# 17  0.259720   0.95250
# 18  0.237469   0.95625
# 19  0.213520   0.96625
# 20  0.193820   0.97750
# 21  0.175244   0.97375
# 22  0.161893   0.97875
# 23  0.154989   0.97750
# 24  0.148973   0.97625

# %%
df.plot()
plt.title("History of loss vs accuracy")
plt.show()

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as model_8)
model_9 = tf.keras.Sequential([
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model
model_9.compile(loss="binary_crossentropy", # we can use strings here too
              optimizer="Adam", # same as tf.keras.optimizers.Adam() with default settings
              metrics=["accuracy"]) 

# Create a learning rate scheduler callback
lr_scheduler = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-4 * 10**(epoch/20)) # traverse a set of learning rate values starting from 1e-4, increasing by 10**(epoch/20) every epoch

# Fit the model (passing the lr_scheduler callback)
history = model_9.fit(X_train, 
                      y_train, 
                      epochs=100,
                      callbacks=[lr_scheduler])
# Out:
# Epoch 1/100
# 25/25 [==============================] - 0s 828us/step - loss: 0.6945 - accuracy: 0.4988
# Epoch 2/100
# 25/25 [==============================] - 0s 878us/step - loss: 0.6938 - accuracy: 0.4975
# Epoch 3/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6930 - accuracy: 0.4963
# Epoch 4/100
# 25/25 [==============================] - 0s 884us/step - loss: 0.6922 - accuracy: 0.4975
# Epoch 5/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6914 - accuracy: 0.5063
# Epoch 6/100
# 25/25 [==============================] - 0s 827us/step - loss: 0.6906 - accuracy: 0.5013
# Epoch 7/100
# 25/25 [==============================] - 0s 868us/step - loss: 0.6898 - accuracy: 0.4950
# Epoch 8/100
# 25/25 [==============================] - 0s 877us/step - loss: 0.6889 - accuracy: 0.5038
# Epoch 9/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6880 - accuracy: 0.5013
# Epoch 10/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6871 - accuracy: 0.5050
# Epoch 11/100
# 25/25 [==============================] - 0s 904us/step - loss: 0.6863 - accuracy: 0.5200
# Epoch 12/100
# 25/25 [==============================] - 0s 944us/step - loss: 0.6856 - accuracy: 0.5163
# Epoch 13/100
# 25/25 [==============================] - 0s 957us/step - loss: 0.6847 - accuracy: 0.5175
# Epoch 14/100
# 25/25 [==============================] - 0s 909us/step - loss: 0.6842 - accuracy: 0.5200
# Epoch 15/100
# 25/25 [==============================] - 0s 939us/step - loss: 0.6835 - accuracy: 0.5213
# Epoch 16/100
# 25/25 [==============================] - 0s 889us/step - loss: 0.6829 - accuracy: 0.5213
# Epoch 17/100
# 25/25 [==============================] - 0s 828us/step - loss: 0.6826 - accuracy: 0.5225
# Epoch 18/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6819 - accuracy: 0.5300
# Epoch 19/100
# 25/25 [==============================] - 0s 808us/step - loss: 0.6816 - accuracy: 0.5312
# Epoch 20/100
# 25/25 [==============================] - 0s 855us/step - loss: 0.6811 - accuracy: 0.5387
# Epoch 21/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6806 - accuracy: 0.5400
# Epoch 22/100
# 25/25 [==============================] - 0s 998us/step - loss: 0.6801 - accuracy: 0.5412
# Epoch 23/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6796 - accuracy: 0.5400
# Epoch 24/100
# 25/25 [==============================] - 0s 942us/step - loss: 0.6790 - accuracy: 0.5425
# Epoch 25/100
# 25/25 [==============================] - 0s 952us/step - loss: 0.6784 - accuracy: 0.5450
# Epoch 26/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6778 - accuracy: 0.5387
# Epoch 27/100
# 25/25 [==============================] - 0s 901us/step - loss: 0.6770 - accuracy: 0.5425
# Epoch 28/100
# 25/25 [==============================] - 0s 922us/step - loss: 0.6760 - accuracy: 0.5537
# Epoch 29/100
# 25/25 [==============================] - 0s 977us/step - loss: 0.6754 - accuracy: 0.5512
# Epoch 30/100
# 25/25 [==============================] - 0s 925us/step - loss: 0.6739 - accuracy: 0.5575
# Epoch 31/100
# 25/25 [==============================] - 0s 940us/step - loss: 0.6726 - accuracy: 0.5500
# Epoch 32/100
# 25/25 [==============================] - 0s 940us/step - loss: 0.6711 - accuracy: 0.5512
# Epoch 33/100
# 25/25 [==============================] - 0s 909us/step - loss: 0.6688 - accuracy: 0.5562
# Epoch 34/100
# 25/25 [==============================] - 0s 947us/step - loss: 0.6672 - accuracy: 0.5612
# Epoch 35/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6660 - accuracy: 0.5888
# Epoch 36/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6625 - accuracy: 0.5625
# Epoch 37/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6560 - accuracy: 0.5813
# Epoch 38/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6521 - accuracy: 0.6025
# Epoch 39/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6415 - accuracy: 0.7088
# Epoch 40/100
# 25/25 [==============================] - 0s 960us/step - loss: 0.6210 - accuracy: 0.7113
# Epoch 41/100
# 25/25 [==============================] - 0s 951us/step - loss: 0.5904 - accuracy: 0.7487
# Epoch 42/100
# 25/25 [==============================] - 0s 926us/step - loss: 0.5688 - accuracy: 0.7312
# Epoch 43/100
# 25/25 [==============================] - 0s 930us/step - loss: 0.5346 - accuracy: 0.7563
# Epoch 44/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.4533 - accuracy: 0.8150
# Epoch 45/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3455 - accuracy: 0.9112
# Epoch 46/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2570 - accuracy: 0.9463
# Epoch 47/100
# 25/25 [==============================] - 0s 887us/step - loss: 0.1968 - accuracy: 0.9575
# Epoch 48/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1336 - accuracy: 0.9700
# Epoch 49/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1310 - accuracy: 0.9613
# Epoch 50/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 0.9700
# Epoch 51/100
# 25/25 [==============================] - 0s 928us/step - loss: 0.1166 - accuracy: 0.9638
# Epoch 52/100
# 25/25 [==============================] - 0s 843us/step - loss: 0.1368 - accuracy: 0.9513
# Epoch 53/100
# 25/25 [==============================] - 0s 968us/step - loss: 0.0879 - accuracy: 0.9787
# Epoch 54/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1187 - accuracy: 0.9588
# Epoch 55/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0733 - accuracy: 0.9712
# Epoch 56/100
# 25/25 [==============================] - 0s 979us/step - loss: 0.1132 - accuracy: 0.9550
# Epoch 57/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.9613
# Epoch 58/100
# 25/25 [==============================] - 0s 940us/step - loss: 0.0665 - accuracy: 0.9750
# Epoch 59/100
# 25/25 [==============================] - 0s 934us/step - loss: 0.1916 - accuracy: 0.9275
# Epoch 60/100
# 25/25 [==============================] - 0s 992us/step - loss: 0.1877 - accuracy: 0.9312
# Epoch 61/100
# 25/25 [==============================] - 0s 851us/step - loss: 0.4017 - accuracy: 0.8612
# Epoch 62/100
# 25/25 [==============================] - 0s 975us/step - loss: 0.1675 - accuracy: 0.9725
# Epoch 63/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0597 - accuracy: 0.9912
# Epoch 64/100
# 25/25 [==============================] - 0s 932us/step - loss: 0.0988 - accuracy: 0.9663
# Epoch 65/100
# 25/25 [==============================] - 0s 921us/step - loss: 0.1005 - accuracy: 0.9588
# Epoch 66/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.2240 - accuracy: 0.9350
# Epoch 67/100
# 25/25 [==============================] - 0s 955us/step - loss: 0.5240 - accuracy: 0.8250
# Epoch 68/100
# 25/25 [==============================] - 0s 942us/step - loss: 0.1650 - accuracy: 0.9600
# Epoch 69/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0569 - accuracy: 0.9850
# Epoch 70/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1858 - accuracy: 0.9275
# Epoch 71/100
# 25/25 [==============================] - 0s 922us/step - loss: 0.3237 - accuracy: 0.8700
# Epoch 72/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1877 - accuracy: 0.9200
# Epoch 73/100
# 25/25 [==============================] - 0s 948us/step - loss: 0.1600 - accuracy: 0.9362
# Epoch 74/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1342 - accuracy: 0.9525
# Epoch 75/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3309 - accuracy: 0.8788
# Epoch 76/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1408 - accuracy: 0.9450
# Epoch 77/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0416 - accuracy: 0.9900
# Epoch 78/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7439 - accuracy: 0.7475
# Epoch 79/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6934 - accuracy: 0.6100
# Epoch 80/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7342 - accuracy: 0.5713
# Epoch 81/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7056 - accuracy: 0.4563
# Epoch 82/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7109 - accuracy: 0.5487
# Epoch 83/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7250 - accuracy: 0.4762
# Epoch 84/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7063 - accuracy: 0.5088
# Epoch 85/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7282 - accuracy: 0.5038
# Epoch 86/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7678 - accuracy: 0.5038
# Epoch 87/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7679 - accuracy: 0.5013
# Epoch 88/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7586 - accuracy: 0.5163
# Epoch 89/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7636 - accuracy: 0.5263
# Epoch 90/100
# 25/25 [==============================] - 0s 991us/step - loss: 0.7855 - accuracy: 0.4938
# Epoch 91/100
# 25/25 [==============================] - 0s 995us/step - loss: 0.8027 - accuracy: 0.5138
# Epoch 92/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7384 - accuracy: 0.4963
# Epoch 93/100
# 25/25 [==============================] - 0s 930us/step - loss: 0.7400 - accuracy: 0.4963
# Epoch 94/100
# 25/25 [==============================] - 0s 887us/step - loss: 0.7581 - accuracy: 0.4938
# Epoch 95/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.8190 - accuracy: 0.4863
# Epoch 96/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.7814 - accuracy: 0.4613
# Epoch 97/100
# 25/25 [==============================] - 0s 915us/step - loss: 0.8057 - accuracy: 0.5013
# Epoch 98/100
# 25/25 [==============================] - 0s 905us/step - loss: 0.9629 - accuracy: 0.4963
# Epoch 99/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.9575 - accuracy: 0.4913
# Epoch 100/100
# 25/25 [==============================] - 0s 1ms/step - loss: 0.8582 - accuracy: 0.4613

# %%
# Plot the learning rate versus the loss
lrs = 1e-4 * (10 ** (np.arange(100)/20))
plt.figure(figsize=(10, 7))
plt.semilogx(lrs, history.history["loss"]) # we want the x-axis (learning rate) to be log scale
plt.xlabel("Learning Rate")
plt.ylabel("Loss")
plt.title("Learning rate vs. loss");

# %%
# Set the random seed
tf.random.set_seed(42)

# Create the model
model_10 = tf.keras.Sequential([
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(4, activation="relu"),
  tf.keras.layers.Dense(1, activation="sigmoid")
])

# Compile the model with the ideal learning rate
model_10.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.Adam(lr=0.02), # to adjust the learning rate, you need to use tf.keras.optimizers.Adam (not "adam")
                metrics=["accuracy"])

# Fit the model for 20 epochs (5 less than before)
history = model_10.fit(X_train, y_train, epochs=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/20
# 25/25 [==============================] - 0s 1ms/step - loss: 0.6837 - accuracy: 0.5600
# Epoch 2/20
# 25/25 [==============================] - 0s 915us/step - loss: 0.6744 - accuracy: 0.5750
# Epoch 3/20
# 25/25 [==============================] - 0s 887us/step - loss: 0.6626 - accuracy: 0.5875
# Epoch 4/20
# 25/25 [==============================] - 0s 858us/step - loss: 0.6332 - accuracy: 0.6388
# Epoch 5/20
# 25/25 [==============================] - 0s 859us/step - loss: 0.5830 - accuracy: 0.7563
# Epoch 6/20
# 25/25 [==============================] - 0s 876us/step - loss: 0.4907 - accuracy: 0.8313
# Epoch 7/20
# 25/25 [==============================] - 0s 829us/step - loss: 0.4251 - accuracy: 0.8450
# Epoch 8/20
# 25/25 [==============================] - 0s 939us/step - loss: 0.3596 - accuracy: 0.8875
# Epoch 9/20
# 25/25 [==============================] - 0s 866us/step - loss: 0.3152 - accuracy: 0.9100
# Epoch 10/20
# 25/25 [==============================] - 0s 920us/step - loss: 0.2512 - accuracy: 0.9500
# Epoch 11/20
# 25/25 [==============================] - 0s 853us/step - loss: 0.2152 - accuracy: 0.9500
# Epoch 12/20
# 25/25 [==============================] - 0s 968us/step - loss: 0.1721 - accuracy: 0.9750
# Epoch 13/20
# 25/25 [==============================] - 0s 1ms/step - loss: 0.1443 - accuracy: 0.9837
# Epoch 14/20
# 25/25 [==============================] - 0s 876us/step - loss: 0.1232 - accuracy: 0.9862
# Epoch 15/20
# 25/25 [==============================] - 0s 992us/step - loss: 0.1085 - accuracy: 0.9850
# Epoch 16/20
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9937
# Epoch 17/20
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0827 - accuracy: 0.9962
# Epoch 18/20
# 25/25 [==============================] - 0s 927us/step - loss: 0.0798 - accuracy: 0.9937
# Epoch 19/20
# 25/25 [==============================] - 0s 964us/step - loss: 0.0845 - accuracy: 0.9875
# Epoch 20/20
# 25/25 [==============================] - 0s 942us/step - loss: 0.0790 - accuracy: 0.9887

# %%
# Evaluate model on the test dataset
model_10.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9900
# [0.05740182101726532, 0.9900000095367432]

# %%
# Plot the decision boundaries for the training and test sets
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.title("Train")
plot_decision_boundary(model_10, X=X_train, y=y_train)
plt.subplot(1, 2, 2)
plt.title("Test")
plot_decision_boundary(model_10, X=X_test, y=y_test)
plt.show()
# Out:
# doing binary classifcation...
# doing binary classifcation...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
y_pred = model_10.predict(X_test)

# %%
confusion_matrix(y_test,tf.round(y_pred))
# Out:
# array([[99,  2],
#        [ 0, 99]])

# %% [markdown]
# More classification evaluation methods
# Alongside the visualizations we've been making, there are a number of different evaluation metrics we can use to evaluate our classification models.
#
# | **Metric name/Evaluation method** | **Defintion** | **Code** |
# | --- | --- | --- |
# | Accuracy | Out of 100 predictions, how many does your model get correct? E.g. 95% accuracy means it gets 95/100 predictions correct. | [`sklearn.metrics.accuracy_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html) or [`tf.keras.metrics.Accuracy()`](tensorflow.org/api_docs/python/tf/keras/metrics/Accuracy) |
# | Precision | Proportion of true positives over total number of samples. Higher precision leads to less false positives (model predicts 1 when it should've been 0). | [`sklearn.metrics.precision_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html) or [`tf.keras.metrics.Precision()`](tensorflow.org/api_docs/python/tf/keras/metrics/Precision) |
# | Recall | Proportion of true positives over total number of true positives and false negatives (model predicts 0 when it should've been 1). Higher recall leads to less false negatives. | [`sklearn.metrics.recall_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html) or [`tf.keras.metrics.Recall()`](tensorflow.org/api_docs/python/tf/keras/metrics/Recall) |
# | F1-score | Combines precision and recall into one metric. 1 is best, 0 is worst. | [`sklearn.metrics.f1_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html) |
# | [Confusion matrix](https://www.dataschool.io/simple-guide-to-confusion-matrix-terminology/)  | Compares the predicted values with the true values in a tabular way, if 100% correct, all values in the matrix will be top left to bottom right (diagnol line). | Custom function or [`sklearn.metrics.plot_confusion_matrix()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.plot_confusion_matrix.html) |
# | Classification report | Collection of some of the main classification metrics such as precision, recall and f1-score. | [`sklearn.metrics.classification_report()`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html) |
# ---
#
#
#
# 🔑 Note: Every classification problem will require different kinds of evaluation methods. But you should be familiar with at least the ones

# %%
import itertools

figsize = (10, 10)

# Create the confusion matrix
cm = confusion_matrix(y_test, tf.round(y_pred))
cm_norm = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] # normalize it
n_classes = cm.shape[0]

# Let's prettify it
fig, ax = plt.subplots(figsize=figsize)
# Create a matrix plot
cax = ax.matshow(cm, cmap=plt.cm.Blues) # https://matplotlib.org/3.2.0/api/_as_gen/matplotlib.axes.Axes.matshow.html
fig.colorbar(cax)

# Create classes
classes = False

if classes:
  labels = classes
else:
  labels = np.arange(cm.shape[0])

# Label the axes
ax.set(title="Confusion Matrix",
       xlabel="Predicted label",
       ylabel="True label",
       xticks=np.arange(n_classes),
       yticks=np.arange(n_classes),
       xticklabels=labels,
       yticklabels=labels)

# Set x-axis labels to bottom
ax.xaxis.set_label_position("bottom")
ax.xaxis.tick_bottom()

# Adjust label size
ax.xaxis.label.set_size(20)
ax.yaxis.label.set_size(20)
ax.title.set_size(20)

# Set threshold for different colors
threshold = (cm.max() + cm.min()) / 2.

# Plot the text on each cell
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
  plt.text(j, i, f"{cm[i, j]} ({cm_norm[i, j]*100:.1f}%)",
           horizontalalignment="center",
           color="white" if cm[i, j] > threshold else "black",
           size=15)

# %%
cm = confusion_matrix(y_test, tf.round(y_pred))
disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=["0","1"])
disp.plot()
